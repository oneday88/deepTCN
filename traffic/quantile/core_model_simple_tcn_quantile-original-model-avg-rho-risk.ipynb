# %%
import os, sys, math, random, time
from datetime import datetime
import _pickle as pickle

import numpy as np
import pandas as pd

import mxnet as mx
from mxnet import autograd, gluon, nd, gpu
from mxnet.gluon import nn

from simple_tcn_quantile import TCN,QuantileLoss
from trainer import nn_trainer
from nnHelper import Gaussian_loss

### The input dataset
ctx = mx.gpu(0)
with open('/home/chenyixiong4/TCN_traffic/data/tensor_prepare_alldata.pkl', 'rb') as f:
    [trainX_dt,train_X2_dt, trainY_dt,testX_dt, test_X2_dt,testY_dt] = pickle.load(f)

# %%
2*(1+2+4+8)*5
# Out:
# 150

# %%
sub_train_X, sub_train_Y = nd.array(trainX_dt, ctx=ctx), nd.array(trainY_dt, ctx=ctx)
sub_valid_X, sub_valid_Y = nd.array(testX_dt, ctx=ctx), nd.array(testY_dt, ctx=ctx)
conv_train_X, conv_valid_X = nd.array(train_X2_dt,ctx=ctx), nd.array(test_X2_dt,ctx=ctx)

sub_train_nd = gluon.data.ArrayDataset(conv_train_X, sub_train_X, sub_train_Y)

# %%
len(sub_train_nd)
# Out:
# 410238

# %%
"""
conv_x = conv_train_X[:128,:]
x = sub_train_X[:128,]
"""
model1 = TCN()
#choose parameters
batch_size= 128
n_epochs=500
"""
The model training
"""
### The model parameters
abs_loss = gluon.loss.L1Loss()
L2_loss = gluon.loss.L2Loss()
huber_loss = gluon.loss.HuberLoss()
normal_loss = Gaussian_loss
Qloss50 = QuantileLoss(quantile_alpha=0.5)
Qloss90 = QuantileLoss(quantile_alpha=0.9)
initializer = mx.initializer.MSRAPrelu()
optimizer = 'adam';
optimizer_params = {'learning_rate': 0.01}

trainer_params_list = {'batch_size': batch_size,'epoch_num':n_epochs,
                 'initializer': initializer, 'loss50': Qloss50, 'loss90': Qloss90,
                'optimizer':optimizer, 'optimizer_params':optimizer_params}
train_mark='testing'
nn_trainer(train_mark, model1, sub_train_nd, conv_valid_X,sub_valid_X, sub_valid_Y, trainer_params_list=trainer_params_list, ctx=ctx)
# Out:
# Epoch 0, valid_loss: 6726.662109
# Epoch 0, avg_rho50: 0.155284,avg_rho90: 0.107156
# time for one epoch: 340.07s
# Epoch 1, valid_loss: 6717.527344
# Epoch 1, avg_rho50: 0.151664,avg_rho90: 0.110351
# time for one epoch: 339.1s
# Epoch 2, valid_loss: 5756.342285
# Epoch 2, avg_rho50: 0.131791,avg_rho90: 0.090894
# time for one epoch: 337.17s
# Epoch 3, valid_loss: 6702.146484
# Epoch 3, avg_rho50: 0.169537,avg_rho90: 0.093767
# time for one epoch: 337.81s
# Epoch 4, valid_loss: 6244.771484
# Epoch 4, avg_rho50: 0.139490,avg_rho90: 0.101932
# time for one epoch: 339.57s
# Epoch 5, valid_loss: 6502.363770
# Epoch 5, avg_rho50: 0.153826,avg_rho90: 0.097751
# time for one epoch: 341.47s
# Epoch 6, valid_loss: 6170.454102
# Epoch 6, avg_rho50: 0.144097,avg_rho90: 0.093974
# time for one epoch: 338.78s
# Epoch 7, valid_loss: 5819.580566
# Epoch 7, avg_rho50: 0.131729,avg_rho90: 0.092564
# time for one epoch: 339.38s
# Epoch 8, valid_loss: 5566.729004
# Epoch 8, avg_rho50: 0.123696,avg_rho90: 0.092309
# time for one epoch: 338.97s
# Epoch 9, valid_loss: 5846.793457
# Epoch 9, avg_rho50: 0.135109,avg_rho90: 0.090385
# time for one epoch: 337.89s
# Epoch 10, valid_loss: 5806.401367
# Epoch 10, avg_rho50: 0.129474,avg_rho90: 0.094759
# time for one epoch: 338.31s
# Epoch 11, valid_loss: 6201.025391
# Epoch 11, avg_rho50: 0.145198,avg_rho90: 0.093604
# time for one epoch: 337.33s
# Epoch 12, valid_loss: 6008.503418
# Epoch 12, avg_rho50: 0.137805,avg_rho90: 0.094137
# time for one epoch: 339.53s
# Epoch 13, valid_loss: 5612.624512
# Epoch 13, avg_rho50: 0.123579,avg_rho90: 0.094516
# time for one epoch: 339.15s
# Epoch 14, valid_loss: 5330.438477
# Epoch 14, avg_rho50: 0.121020,avg_rho90: 0.085224
# time for one epoch: 339.77s
# Epoch 15, valid_loss: 5738.207031
# Epoch 15, avg_rho50: 0.130715,avg_rho90: 0.090206
# time for one epoch: 339.7s
# Epoch 16, valid_loss: 5898.863770
# Epoch 16, avg_rho50: 0.129302,avg_rho90: 0.099015
# time for one epoch: 341.06s
# Epoch 17, valid_loss: 5418.943359
# Epoch 17, avg_rho50: 0.124710,avg_rho90: 0.087690
# time for one epoch: 337.55s
# Epoch 18, valid_loss: 6447.416504
# Epoch 18, avg_rho50: 0.156111,avg_rho90: 0.095183
# time for one epoch: 337.08s
# Epoch 19, valid_loss: 6101.264648
# Epoch 19, avg_rho50: 0.145812,avg_rho90: 0.096354
# time for one epoch: 338.99s
# Epoch 20, valid_loss: 6000.130859
# Epoch 20, avg_rho50: 0.138929,avg_rho90: 0.094129
# time for one epoch: 337.26s
# Epoch 21, valid_loss: 5864.750977
# Epoch 21, avg_rho50: 0.141396,avg_rho90: 0.086890
# time for one epoch: 338.82s
# Epoch 22, valid_loss: 5242.904297
# Epoch 22, avg_rho50: 0.117441,avg_rho90: 0.085848
# time for one epoch: 338.44s
# Epoch 23, valid_loss: 5335.015625
# Epoch 23, avg_rho50: 0.123071,avg_rho90: 0.084348
# time for one epoch: 338.83s
# Epoch 24, valid_loss: 5553.533691
# Epoch 24, avg_rho50: 0.131141,avg_rho90: 0.086049
# time for one epoch: 338.36s
# Epoch 25, valid_loss: 5658.304688
# Epoch 25, avg_rho50: 0.130438,avg_rho90: 0.089159
# time for one epoch: 337.39s
# Epoch 26, valid_loss: 5342.780273
# Epoch 26, avg_rho50: 0.121921,avg_rho90: 0.086062
# time for one epoch: 338.89s
# Epoch 27, valid_loss: 5134.373047
# Epoch 27, avg_rho50: 0.116808,avg_rho90: 0.083000
# time for one epoch: 340.22s
# Epoch 28, valid_loss: 5554.530273
# Epoch 28, avg_rho50: 0.130793,avg_rho90: 0.087681
# time for one epoch: 341.12s
# Epoch 29, valid_loss: 7182.820801
# Epoch 29, avg_rho50: 0.178369,avg_rho90: 0.102082
# time for one epoch: 340.4s
# Epoch 30, valid_loss: 5216.170410
# Epoch 30, avg_rho50: 0.117200,avg_rho90: 0.085076
# time for one epoch: 338.79s
# Epoch 31, valid_loss: 5180.958008
# Epoch 31, avg_rho50: 0.118987,avg_rho90: 0.081809
# time for one epoch: 337.68s
# Epoch 32, valid_loss: 5459.993164
# Epoch 32, avg_rho50: 0.130222,avg_rho90: 0.081797
# time for one epoch: 341.29s
# Epoch 33, valid_loss: 5425.497070
# Epoch 33, avg_rho50: 0.124587,avg_rho90: 0.087142
# time for one epoch: 340.51s
# Epoch 34, valid_loss: 5941.787109
# Epoch 34, avg_rho50: 0.146019,avg_rho90: 0.084610
# time for one epoch: 333.28s
# Epoch 35, valid_loss: 5156.698242
# Epoch 35, avg_rho50: 0.118101,avg_rho90: 0.082191
# time for one epoch: 337.55s
# Epoch 36, valid_loss: 5489.463867
# Epoch 36, avg_rho50: 0.130388,avg_rho90: 0.082984
# time for one epoch: 339.04s
# Epoch 37, valid_loss: 5593.416016
# Epoch 37, avg_rho50: 0.132987,avg_rho90: 0.084894
# time for one epoch: 337.39s
# Epoch 38, valid_loss: 5260.740234
# Epoch 38, avg_rho50: 0.124986,avg_rho90: 0.078806
# time for one epoch: 336.18s
# Epoch 39, valid_loss: 5823.105469
# Epoch 39, avg_rho50: 0.132854,avg_rho90: 0.092400
# time for one epoch: 335.23s
# Epoch 40, valid_loss: 5086.465820
# Epoch 40, avg_rho50: 0.116864,avg_rho90: 0.080582
# time for one epoch: 338.25s
# Epoch 41, valid_loss: 5775.914062
# Epoch 41, avg_rho50: 0.135263,avg_rho90: 0.088934
# time for one epoch: 336.92s
# Epoch 42, valid_loss: 5226.539062
# Epoch 42, avg_rho50: 0.114106,avg_rho90: 0.088126
# time for one epoch: 340.31s
# Epoch 43, valid_loss: 5179.443848
# Epoch 43, avg_rho50: 0.119394,avg_rho90: 0.081562
# time for one epoch: 338.25s
# Epoch 44, valid_loss: 5089.017090
# Epoch 44, avg_rho50: 0.114441,avg_rho90: 0.082653
# time for one epoch: 336.02s
# Epoch 45, valid_loss: 5512.259766
# Epoch 45, avg_rho50: 0.126111,avg_rho90: 0.087135
# time for one epoch: 335.82s
# Epoch 46, valid_loss: 5273.657227
# Epoch 46, avg_rho50: 0.122854,avg_rho90: 0.081314
# time for one epoch: 336.78s
# Epoch 47, valid_loss: 6889.291992
# Epoch 47, avg_rho50: 0.173033,avg_rho90: 0.094011
# time for one epoch: 335.94s
# Epoch 48, valid_loss: 5181.939453
# Epoch 48, avg_rho50: 0.118149,avg_rho90: 0.082496
# time for one epoch: 336.61s
# Epoch 49, valid_loss: 5501.739258
# Epoch 49, avg_rho50: 0.125425,avg_rho90: 0.089329
# time for one epoch: 337.52s
# Epoch 50, valid_loss: 5629.410156
# Epoch 50, avg_rho50: 0.127556,avg_rho90: 0.092359
# time for one epoch: 336.36s
# Epoch 51, valid_loss: 5204.028320
# Epoch 51, avg_rho50: 0.116937,avg_rho90: 0.084231
# time for one epoch: 337.65s
# Epoch 52, valid_loss: 5325.040039
# Epoch 52, avg_rho50: 0.118842,avg_rho90: 0.087346
# time for one epoch: 338.77s
# Epoch 53, valid_loss: 5119.571289
# Epoch 53, avg_rho50: 0.116638,avg_rho90: 0.081305
# time for one epoch: 336.39s
# Epoch 54, valid_loss: 6042.703125
# Epoch 54, avg_rho50: 0.139622,avg_rho90: 0.098250
# time for one epoch: 335.84s
# Epoch 55, valid_loss: 5237.122070
# Epoch 55, avg_rho50: 0.120834,avg_rho90: 0.082143
# time for one epoch: 336.57s
# Epoch 56, valid_loss: 5724.527832
# Epoch 56, avg_rho50: 0.131684,avg_rho90: 0.089286
# time for one epoch: 334.78s
# Epoch 57, valid_loss: 5343.781738
# Epoch 57, avg_rho50: 0.123289,avg_rho90: 0.083327
# time for one epoch: 336.64s
# Epoch 58, valid_loss: 5431.634766
# Epoch 58, avg_rho50: 0.123403,avg_rho90: 0.086470
# time for one epoch: 338.21s
# Epoch 59, valid_loss: 5187.534180
# Epoch 59, avg_rho50: 0.115721,avg_rho90: 0.086309
# time for one epoch: 336.36s
# Epoch 60, valid_loss: 5398.883301
# Epoch 60, avg_rho50: 0.119120,avg_rho90: 0.090779
# time for one epoch: 337.65s
# Epoch 61, valid_loss: 5296.599609
# Epoch 61, avg_rho50: 0.118032,avg_rho90: 0.086918
# time for one epoch: 337.79s
# Epoch 62, valid_loss: 5200.004883
# Epoch 62, avg_rho50: 0.114380,avg_rho90: 0.087237
# time for one epoch: 337.75s
# Epoch 63, valid_loss: 5030.500488
# Epoch 63, avg_rho50: 0.114988,avg_rho90: 0.080023
# time for one epoch: 338.32s
# Epoch 64, valid_loss: 4981.980957
# Epoch 64, avg_rho50: 0.112577,avg_rho90: 0.080467
# time for one epoch: 338.65s
# Epoch 65, valid_loss: 5315.762207
# Epoch 65, avg_rho50: 0.120081,avg_rho90: 0.085507
# time for one epoch: 339.6s
# Epoch 66, valid_loss: 4978.363770
# Epoch 66, avg_rho50: 0.112864,avg_rho90: 0.079791
# time for one epoch: 339.52s
# Epoch 67, valid_loss: 5242.739258
# Epoch 67, avg_rho50: 0.120984,avg_rho90: 0.082989
# time for one epoch: 337.19s
# Epoch 68, valid_loss: 5452.940430
# Epoch 68, avg_rho50: 0.127959,avg_rho90: 0.084685
# time for one epoch: 336.85s
# Epoch 69, valid_loss: 5153.267578
# Epoch 69, avg_rho50: 0.117194,avg_rho90: 0.082454
# time for one epoch: 338.84s
# Epoch 70, valid_loss: 5072.095215
# Epoch 70, avg_rho50: 0.112630,avg_rho90: 0.084043
# time for one epoch: 336.38s
# Epoch 71, valid_loss: 5129.717773
# Epoch 71, avg_rho50: 0.118313,avg_rho90: 0.080235
# time for one epoch: 338.85s
# Epoch 72, valid_loss: 5018.933594
# Epoch 72, avg_rho50: 0.115145,avg_rho90: 0.078903
# time for one epoch: 337.38s
# Epoch 73, valid_loss: 5586.228027
# Epoch 73, avg_rho50: 0.127699,avg_rho90: 0.087433
# time for one epoch: 333.35s
# Epoch 74, valid_loss: 5054.636719
# Epoch 74, avg_rho50: 0.115230,avg_rho90: 0.080302
# time for one epoch: 335.99s
# Epoch 75, valid_loss: 4976.710938
# Epoch 75, avg_rho50: 0.110506,avg_rho90: 0.081890
# time for one epoch: 336.58s
# Epoch 76, valid_loss: 5552.709961
# Epoch 76, avg_rho50: 0.125193,avg_rho90: 0.089556
# time for one epoch: 334.88s
# Epoch 77, valid_loss: 5212.198730
# Epoch 77, avg_rho50: 0.116961,avg_rho90: 0.084489
# time for one epoch: 337.09s
# Epoch 78, valid_loss: 5321.159180
# Epoch 78, avg_rho50: 0.120054,avg_rho90: 0.085213
# time for one epoch: 336.78s
# Epoch 79, valid_loss: 6344.321777
# Epoch 79, avg_rho50: 0.159886,avg_rho90: 0.085979
# time for one epoch: 336.31s
# Epoch 80, valid_loss: 5404.991211
# Epoch 80, avg_rho50: 0.117920,avg_rho90: 0.091577
# time for one epoch: 337.86s
# Epoch 81, valid_loss: 5367.517578
# Epoch 81, avg_rho50: 0.124700,avg_rho90: 0.083763
# time for one epoch: 333.61s
# Epoch 82, valid_loss: 5480.350586
# Epoch 82, avg_rho50: 0.124076,avg_rho90: 0.087832
# time for one epoch: 335.13s
# Epoch 83, valid_loss: 5066.642578
# Epoch 83, avg_rho50: 0.113269,avg_rho90: 0.082434
# time for one epoch: 339.87s
# Epoch 84, valid_loss: 5349.253906
# Epoch 84, avg_rho50: 0.119958,avg_rho90: 0.086720
# time for one epoch: 335.72s
# Epoch 85, valid_loss: 5190.025391
# Epoch 85, avg_rho50: 0.117599,avg_rho90: 0.083288
# time for one epoch: 335.4s
# Epoch 86, valid_loss: 5550.790039
# Epoch 86, avg_rho50: 0.129483,avg_rho90: 0.085186
# time for one epoch: 337.59s
# Epoch 87, valid_loss: 5093.875977
# Epoch 87, avg_rho50: 0.114638,avg_rho90: 0.082907
# time for one epoch: 336.58s
# Epoch 88, valid_loss: 5236.884277
# Epoch 88, avg_rho50: 0.120934,avg_rho90: 0.082013
# time for one epoch: 336.55s
# Epoch 89, valid_loss: 5369.935547
# Epoch 89, avg_rho50: 0.121557,avg_rho90: 0.085852
# time for one epoch: 338.08s
# Epoch 90, valid_loss: 5440.460449
# Epoch 90, avg_rho50: 0.126720,avg_rho90: 0.083555
# time for one epoch: 340.41s
# Epoch 91, valid_loss: 5750.948242
# Epoch 91, avg_rho50: 0.130375,avg_rho90: 0.091142
# time for one epoch: 338.96s
# Epoch 92, valid_loss: 5307.143555
# Epoch 92, avg_rho50: 0.126238,avg_rho90: 0.079260
# time for one epoch: 336.11s
# Epoch 93, valid_loss: 5094.273438
# Epoch 93, avg_rho50: 0.114355,avg_rho90: 0.082929
# time for one epoch: 336.75s
# Epoch 94, valid_loss: 5145.224609
# Epoch 94, avg_rho50: 0.117685,avg_rho90: 0.081951
# time for one epoch: 336.9s
# Epoch 95, valid_loss: 5169.124023
# Epoch 95, avg_rho50: 0.117274,avg_rho90: 0.082276
# time for one epoch: 336.37s
# Epoch 96, valid_loss: 5605.157227
# Epoch 96, avg_rho50: 0.131845,avg_rho90: 0.085396
# time for one epoch: 336.87s
# Epoch 97, valid_loss: 5278.208008
# Epoch 97, avg_rho50: 0.119921,avg_rho90: 0.084230
# time for one epoch: 339.63s
# Epoch 98, valid_loss: 5083.614746
# Epoch 98, avg_rho50: 0.117577,avg_rho90: 0.079623
# time for one epoch: 338.97s
# Epoch 99, valid_loss: 5679.913574
# Epoch 99, avg_rho50: 0.130994,avg_rho90: 0.088774
# time for one epoch: 340.76s
# Epoch 100, valid_loss: 5380.957031
# Epoch 100, avg_rho50: 0.120143,avg_rho90: 0.087699
# time for one epoch: 335.83s
# Epoch 101, valid_loss: 5876.407227
# Epoch 101, avg_rho50: 0.135874,avg_rho90: 0.091760
# time for one epoch: 338.14s
# Epoch 102, valid_loss: 5064.704102
# Epoch 102, avg_rho50: 0.113426,avg_rho90: 0.082517
# time for one epoch: 337.62s
# Epoch 103, valid_loss: 5963.004883
# Epoch 103, avg_rho50: 0.140310,avg_rho90: 0.090406
# time for one epoch: 336.2s
# Epoch 104, valid_loss: 5289.863281
# Epoch 104, avg_rho50: 0.124122,avg_rho90: 0.080303
# time for one epoch: 338.55s
# Epoch 105, valid_loss: 5509.301758
# Epoch 105, avg_rho50: 0.126100,avg_rho90: 0.087613
# time for one epoch: 337.07s
# Epoch 106, valid_loss: 5164.336914
# Epoch 106, avg_rho50: 0.119121,avg_rho90: 0.080900
# time for one epoch: 337.38s
# Epoch 107, valid_loss: 5207.593750
# Epoch 107, avg_rho50: 0.116404,avg_rho90: 0.084778
# time for one epoch: 337.19s
# Epoch 108, valid_loss: 4986.722168
# Epoch 108, avg_rho50: 0.111913,avg_rho90: 0.081092
# time for one epoch: 337.61s
# Epoch 109, valid_loss: 6102.033203
# Epoch 109, avg_rho50: 0.139370,avg_rho90: 0.095117
# time for one epoch: 337.54s
# Epoch 110, valid_loss: 5276.077148
# Epoch 110, avg_rho50: 0.121489,avg_rho90: 0.083278
# time for one epoch: 337.13s
# Epoch 111, valid_loss: 5104.418945
# Epoch 111, avg_rho50: 0.114820,avg_rho90: 0.082928
# time for one epoch: 338.53s
# Epoch 112, valid_loss: 5448.477539
# Epoch 112, avg_rho50: 0.124165,avg_rho90: 0.086426
# time for one epoch: 336.79s
# Epoch 113, valid_loss: 5320.538086
# Epoch 113, avg_rho50: 0.119976,avg_rho90: 0.085476
# time for one epoch: 334.9s
# Epoch 114, valid_loss: 5577.333984
# Epoch 114, avg_rho50: 0.125336,avg_rho90: 0.091380
# time for one epoch: 337.29s
# Epoch 115, valid_loss: 5496.233398
# Epoch 115, avg_rho50: 0.123426,avg_rho90: 0.088781
# time for one epoch: 338.49s
# Epoch 116, valid_loss: 5737.501953
# Epoch 116, avg_rho50: 0.130477,avg_rho90: 0.090625
# time for one epoch: 339.16s
# Epoch 117, valid_loss: 5269.854492
# Epoch 117, avg_rho50: 0.119923,avg_rho90: 0.084038
# time for one epoch: 335.86s
# Epoch 118, valid_loss: 5085.759766
# Epoch 118, avg_rho50: 0.115953,avg_rho90: 0.081245
# time for one epoch: 338.45s
# Epoch 119, valid_loss: 5640.268555
# Epoch 119, avg_rho50: 0.127982,avg_rho90: 0.089609
# time for one epoch: 339.18s
# Epoch 120, valid_loss: 5686.110352
# Epoch 120, avg_rho50: 0.127573,avg_rho90: 0.092548
# time for one epoch: 336.79s
# Epoch 121, valid_loss: 5402.890625
# Epoch 121, avg_rho50: 0.121382,avg_rho90: 0.088204
# time for one epoch: 335.79s
# Epoch 122, valid_loss: 5879.831055
# Epoch 122, avg_rho50: 0.132728,avg_rho90: 0.094482
# time for one epoch: 335.92s
# Epoch 123, valid_loss: 5434.050781
# Epoch 123, avg_rho50: 0.125291,avg_rho90: 0.086117
# time for one epoch: 337.53s
# Epoch 124, valid_loss: 4985.073242
# Epoch 124, avg_rho50: 0.114059,avg_rho90: 0.079482
# time for one epoch: 338.4s
# Epoch 125, valid_loss: 6093.336426
# Epoch 125, avg_rho50: 0.137286,avg_rho90: 0.099207
# time for one epoch: 338.63s
# Epoch 126, valid_loss: 5670.493164
# Epoch 126, avg_rho50: 0.126303,avg_rho90: 0.092316
# time for one epoch: 337.9s
# Epoch 127, valid_loss: 5464.421875
# Epoch 127, avg_rho50: 0.124085,avg_rho90: 0.087784
# time for one epoch: 340.09s
# Epoch 128, valid_loss: 5204.408691
# Epoch 128, avg_rho50: 0.115797,avg_rho90: 0.085766
# time for one epoch: 340.24s
# Epoch 129, valid_loss: 5502.132812
# Epoch 129, avg_rho50: 0.127216,avg_rho90: 0.086303
# time for one epoch: 337.96s
# Epoch 130, valid_loss: 5610.521484
# Epoch 130, avg_rho50: 0.126463,avg_rho90: 0.090785
# time for one epoch: 339.69s
# Epoch 131, valid_loss: 5262.551758
# Epoch 131, avg_rho50: 0.121149,avg_rho90: 0.082860
# time for one epoch: 336.97s
# Epoch 132, valid_loss: 5462.628906
# Epoch 132, avg_rho50: 0.126868,avg_rho90: 0.085110
# time for one epoch: 335.05s
# Epoch 133, valid_loss: 5203.186523
# Epoch 133, avg_rho50: 0.113621,avg_rho90: 0.088002
# time for one epoch: 336.34s
# Epoch 134, valid_loss: 5572.091797
# Epoch 134, avg_rho50: 0.126147,avg_rho90: 0.089497
# time for one epoch: 337.42s
# Epoch 135, valid_loss: 6246.574219
# Epoch 135, avg_rho50: 0.148210,avg_rho90: 0.095266
# time for one epoch: 336.49s
# Epoch 136, valid_loss: 5234.431641
# Epoch 136, avg_rho50: 0.119725,avg_rho90: 0.083603
# time for one epoch: 338.42s
# Epoch 137, valid_loss: 5346.105957
# Epoch 137, avg_rho50: 0.121070,avg_rho90: 0.085609
# time for one epoch: 338.11s
# Epoch 138, valid_loss: 5134.933594
# Epoch 138, avg_rho50: 0.113813,avg_rho90: 0.085228
# time for one epoch: 334.28s
# Epoch 139, valid_loss: 5716.710938
# Epoch 139, avg_rho50: 0.129399,avg_rho90: 0.090716
# time for one epoch: 339.06s
# Epoch 140, valid_loss: 5694.189453
# Epoch 140, avg_rho50: 0.134910,avg_rho90: 0.087264
# time for one epoch: 336.2s
# Epoch 141, valid_loss: 5496.506348
# Epoch 141, avg_rho50: 0.124315,avg_rho90: 0.087780
# time for one epoch: 336.93s
# Epoch 142, valid_loss: 5414.762695
# Epoch 142, avg_rho50: 0.125788,avg_rho90: 0.085148
# time for one epoch: 336.42s
# Epoch 143, valid_loss: 6030.704102
# Epoch 143, avg_rho50: 0.142005,avg_rho90: 0.091975
# time for one epoch: 336.6s
# Epoch 144, valid_loss: 5428.436523
# Epoch 144, avg_rho50: 0.124869,avg_rho90: 0.086052
# time for one epoch: 335.39s
# Epoch 145, valid_loss: 5372.097168
# Epoch 145, avg_rho50: 0.123467,avg_rho90: 0.085208
# time for one epoch: 336.72s
# Epoch 146, valid_loss: 5293.877930
# Epoch 146, avg_rho50: 0.120402,avg_rho90: 0.085386
# time for one epoch: 335.26s
# Epoch 147, valid_loss: 5306.910645
# Epoch 147, avg_rho50: 0.124118,avg_rho90: 0.082430
# time for one epoch: 339.93s
# Epoch 148, valid_loss: 5540.454590
# Epoch 148, avg_rho50: 0.128074,avg_rho90: 0.087567
# time for one epoch: 338.57s
# Epoch 149, valid_loss: 5791.562012
# Epoch 149, avg_rho50: 0.132334,avg_rho90: 0.092996
# time for one epoch: 336.44s
# Epoch 150, valid_loss: 5419.954102
# Epoch 150, avg_rho50: 0.121396,avg_rho90: 0.088116
# time for one epoch: 340.77s
# Epoch 151, valid_loss: 5858.068359
# Epoch 151, avg_rho50: 0.133500,avg_rho90: 0.094065
# time for one epoch: 336.41s
# Epoch 152, valid_loss: 5526.171387
# Epoch 152, avg_rho50: 0.124709,avg_rho90: 0.088907
# time for one epoch: 336.21s
# Epoch 153, valid_loss: 5816.572754
# Epoch 153, avg_rho50: 0.134119,avg_rho90: 0.092995
# time for one epoch: 337.26s
# Epoch 154, valid_loss: 5443.458984
# Epoch 154, avg_rho50: 0.129413,avg_rho90: 0.083320
# time for one epoch: 337.22s
# Epoch 155, valid_loss: 5539.551758
# Epoch 155, avg_rho50: 0.127269,avg_rho90: 0.086818
# time for one epoch: 335.84s
# Epoch 156, valid_loss: 5344.610352
# Epoch 156, avg_rho50: 0.121352,avg_rho90: 0.085363
# time for one epoch: 336.06s
# Epoch 157, valid_loss: 6293.341797
# Epoch 157, avg_rho50: 0.143375,avg_rho90: 0.099680
# time for one epoch: 335.47s
# Epoch 158, valid_loss: 5449.846680
# Epoch 158, avg_rho50: 0.127966,avg_rho90: 0.084423
# time for one epoch: 338.81s
# Epoch 159, valid_loss: 5390.662598
# Epoch 159, avg_rho50: 0.123938,avg_rho90: 0.084965
# time for one epoch: 338.95s
# Epoch 160, valid_loss: 5982.464844
# Epoch 160, avg_rho50: 0.137733,avg_rho90: 0.093745
# time for one epoch: 337.82s
# Epoch 161, valid_loss: 5541.543457
# Epoch 161, avg_rho50: 0.127373,avg_rho90: 0.087067
# time for one epoch: 336.08s
# Epoch 162, valid_loss: 5682.931641
# Epoch 162, avg_rho50: 0.129786,avg_rho90: 0.090283
# time for one epoch: 337.08s
# Epoch 163, valid_loss: 5939.360840
# Epoch 163, avg_rho50: 0.132911,avg_rho90: 0.097436
# time for one epoch: 337.41s
# Epoch 164, valid_loss: 5808.705078
# Epoch 164, avg_rho50: 0.133430,avg_rho90: 0.091951
# time for one epoch: 338.79s
# Epoch 165, valid_loss: 5791.104492
# Epoch 165, avg_rho50: 0.133522,avg_rho90: 0.090765
# time for one epoch: 338.66s
# Epoch 166, valid_loss: 5459.506836
# Epoch 166, avg_rho50: 0.123690,avg_rho90: 0.087759
# time for one epoch: 338.78s
# Epoch 167, valid_loss: 5482.990234
# Epoch 167, avg_rho50: 0.127652,avg_rho90: 0.087554
# time for one epoch: 339.78s
# Epoch 168, valid_loss: 5232.120605
# Epoch 168, avg_rho50: 0.119507,avg_rho90: 0.084300
# time for one epoch: 336.34s
# Epoch 169, valid_loss: 5564.927734
# Epoch 169, avg_rho50: 0.132650,avg_rho90: 0.085438
# time for one epoch: 336.65s
# Epoch 170, valid_loss: 5899.768066
# Epoch 170, avg_rho50: 0.135437,avg_rho90: 0.093158
# time for one epoch: 337.78s
# Epoch 171, valid_loss: 5714.135254
# Epoch 171, avg_rho50: 0.130474,avg_rho90: 0.090377
# time for one epoch: 335.89s
# Epoch 172, valid_loss: 6066.631836
# Epoch 172, avg_rho50: 0.149028,avg_rho90: 0.087282
# time for one epoch: 335.21s
# Epoch 173, valid_loss: 5245.886719
# Epoch 173, avg_rho50: 0.122419,avg_rho90: 0.082045
# time for one epoch: 337.07s
# Epoch 174, valid_loss: 5655.742188
# Epoch 174, avg_rho50: 0.134153,avg_rho90: 0.088813
# time for one epoch: 338.02s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-8a91d85df64c> in <module>()
#      25                 'optimizer':optimizer, 'optimizer_params':optimizer_params}
#      26 train_mark='testing'
# ---> 27 nn_trainer(train_mark, model1, sub_train_nd, conv_valid_X,sub_valid_X, sub_valid_Y, trainer_params_list=trainer_params_list, ctx=ctx)
#
# /work/TCN_traffic/quantile/trainer.py in nn_trainer(train_mark, model, train_data, test_conv_X, test_data_X, test_data_Y, trainer_params_list, ctx)
#     107             loss.backward()
#     108             trainer.step(batch_size,ignore_stale_grad=True)
# --> 109             train_loss += nd.sum(loss).asscalar()
#     110             #print(train_loss)
#     111             k += 1
#
# /usr/local/anaconda3/lib/python3.6/site-packages/mxnet/ndarray/ndarray.py in asscalar(self)
#    1892         if self.shape != (1,):
#    1893             raise ValueError("The current array is not a scalar")
# -> 1894         return self.asnumpy()[0]
#    1895
#    1896     def astype(self, dtype, copy=True):
#
# /usr/local/anaconda3/lib/python3.6/site-packages/mxnet/ndarray/ndarray.py in asnumpy(self)
#    1874             self.handle,
#    1875             data.ctypes.data_as(ctypes.c_void_p),
# -> 1876             ctypes.c_size_t(data.size)))
#    1877         return data
#    1878
#
# KeyboardInterrupt:

# %%
Epoch 72, avg_rho50: 0.115145,avg_rho90: 0.078903
